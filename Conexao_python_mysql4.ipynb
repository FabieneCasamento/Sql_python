# %%
import mysql.connector

# Configurar a conexão com o banco de dados
conexao = mysql.connector.connect(
    host='localhost',
    user='root',
    password='admin',
    database='clientes_banco_backup',
)

# Criar um cursor
cursor = conexao.cursor()

# Executar a consulta SQL para selecionar todos os dados da tabela
query = "SELECT * FROM clientes"
cursor.execute(query)

# Obter todos os resultados da consulta
resultados = cursor.fetchall()

# Exibir os resultados
for linha in resultados:
    print(linha)

# Fechar o cursor e a conexão
#cursor.close()
#conexao.close()
# Out:
# (1, 'Ruben', 'Torres', '1985-08-07', 'C', 'M', 'ruben35@hotmail.com', '(85) 94132-1176', 60000, 3, 'Pós-graduado')
# (2, 'Christy', 'Zhu', '1988-02-10', 'S', 'F', 'christy12@hotmail.com', '(41) 96270-6086', 70000, 0, 'Pós-graduado')
# (3, 'Elizabeth', 'Johnson', '1988-08-03', 'S', 'F', 'elizabeth5@gmail.com', '(31) 92039-5832', 80000, 5, 'Pós-graduado')
# (4, 'Julio', 'Ruiz', '1985-07-31', 'S', 'M', 'julio1@hotmail.com', '(62) 93391-5891', 70000, 0, 'Pós-graduado')
# (5, 'Janet', 'Alvarez', '1985-12-01', 'S', 'F', 'janet9@gmail.com', '(21) 93379-3743', 70000, 0, 'Pós-graduado')
# (6, 'Marco', 'Mehta', '1984-05-04', 'C', 'M', 'marco14@outlook.com', '(85) 99019-3803', 60000, 3, 'Pós-graduado')
# (7, 'Rob', 'Verhoff', '1984-07-02', 'S', 'F', 'rob4@hotmail.com', '(11) 98162-4760', 60000, 4, 'Pós-graduado')
# (8, 'Shannon', 'Carlson', '1984-03-27', 'S', 'M', 'shannon38@gmail.com', '(85) 96795-9950', 70000, 0, 'Pós-graduado')
# ...

# %%
import pandas as pd
# Consulta SQL para selecionar todos os dados da tabela
query = "SELECT * FROM clientes"

# Leia os dados da tabela em um DataFrame do pandas
df = pd.read_sql(query, conexao)

# Exiba o DataFrame
display(df)
# Out:
# /tmp/ipykernel_8614/3444002611.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conexao)
#     ID_Cliente       Nome Sobrenome Data_Nascimento Estado_Civil Sexo  \
# 0            1      Ruben    Torres      1985-08-07            C    M
# 1            2    Christy       Zhu      1988-02-10            S    F
# 2            3  Elizabeth   Johnson      1988-08-03            S    F
# 3            4      Julio      Ruiz      1985-07-31            S    M
# 4            5      Janet   Alvarez      1985-12-01            S    F
# ..         ...        ...       ...             ...          ...  ...
# 95          96    Mallory     Rubio      1981-04-26            S    F
# 96          97       Adam      Ross      1981-03-03            C    M
# 97          98    Latasha   Navarro      1980-09-10            S    F
# ...

# %%
#selecionar algumas colunas da tabela clientes
query = "SELECT ID_Cliente, Nome, Data_Nascimento, Email FROM clientes;"

#identacao 
#query = "SELECT ID_Cliente, Nome, Data_Nascimento, Email FROM clientes;"


cursor.execute(query)

resultados3= cursor.fetchall()

#display(resultados3)

display(resultados3)
# Out:
# [(1, 'Ruben', '1985-08-07', 'ruben35@hotmail.com'),
#  (2, 'Christy', '1988-02-10', 'christy12@hotmail.com'),
#  (3, 'Elizabeth', '1988-08-03', 'elizabeth5@gmail.com'),
#  (4, 'Julio', '1985-07-31', 'julio1@hotmail.com'),
#  (5, 'Janet', '1985-12-01', 'janet9@gmail.com'),
#  (6, 'Marco', '1984-05-04', 'marco14@outlook.com'),
#  (7, 'Rob', '1984-07-02', 'rob4@hotmail.com'),
#  (8, 'Shannon', '1984-03-27', 'shannon38@gmail.com'),
#  (9, 'Jacquelyn', '1984-02-01', 'jacquelyn20@hotmail.com'),
#  (10, 'Curtis', '1983-10-30', 'curtis9@outlook.com'),
#  (11, 'Lauren', '1988-01-13', 'lauren41@hotmail.com'),
#  (12, 'Ian', '1988-08-01', 'ian47@gmail.com'),
#  (13, 'Sydney', '1988-05-04', 'sydney23@gmail.com'),
#  (14, 'Chloe', '1999-02-22', 'chloe23@hotmail.com'),
#  (15, 'Wyatt', '1999-04-23', 'wyatt32@gmail.com'),
#  (16, 'Shannon', '1964-06-21', 'shannon1@hotmail.com'),
#  (17, 'Clarence', '1964-10-04', 'clarence32@outlook.com'),
#  (18, 'Jordan', '1998-09-15', 'jordan73@gmail.com'),
# ...

# %%
#dar nomes nas colunas (AS)
#selecionar algumas colunas da tabela clientes
query = "SELECT ID_Cliente AS 'ID Cliente', Nome AS 'Nome do Cliente', Data_Nascimento AS 'Data de Nascimento', Email AS 'E-mail do Cliente' FROM clientes;"

#identacao 
#query = "SELECT ID_Cliente, Nome, Data_Nascimento, Email FROM clientes;"


cursor.execute(query)

resultados3= cursor.fetchall()

#display(resultados3)

resultados3

df2 = pd.read_sql(query, conexao)

# Exiba o DataFrame
display(df2)
# Out:
# /tmp/ipykernel_8614/3639893590.py:17: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df2 = pd.read_sql(query, conexao)
#     ID Cliente Nome do Cliente Data de Nascimento      E-mail do Cliente
# 0            1           Ruben         1985-08-07    ruben35@hotmail.com
# 1            2         Christy         1988-02-10  christy12@hotmail.com
# 2            3       Elizabeth         1988-08-03   elizabeth5@gmail.com
# 3            4           Julio         1985-07-31     julio1@hotmail.com
# 4            5           Janet         1985-12-01       janet9@gmail.com
# ..         ...             ...                ...                    ...
# 95          96         Mallory         1981-04-26   mallory7@hotmail.com
# 96          97            Adam         1981-03-03      adam2@hotmail.com
# ...

# %% [markdown]
# # selecionar apenas as 5 primeiras linhas da tabela dos produtos

# %%
#selecionar algumas colunas da tabela clientes
query = "SELECT * FROM clientes LIMIT 5;"


cursor.execute(query)

novo= cursor.fetchall()

display(novo)
# Out:
# [(1,
#   'Ruben',
#   'Torres',
#   '1985-08-07',
#   'C',
#   'M',
#   'ruben35@hotmail.com',
#   '(85) 94132-1176',
#   60000,
#   3,
#   'Pós-graduado'),
#  (2,
#   'Christy',
#   'Zhu',
#   '1988-02-10',
#   'S',
#   'F',
#   'christy12@hotmail.com',
#   '(41) 96270-6086',
#   70000,
#   0,
#   'Pós-graduado'),
#  (3,
#   'Elizabeth',
#   'Johnson',
#   '1988-08-03',
#   'S',
#   'F',
#   'elizabeth5@gmail.com',
#   '(31) 92039-5832',
#   80000,
#   5,
#   'Pós-graduado'),
#  (4,
#   'Julio',
#   'Ruiz',
#   '1985-07-31',
#   'S',
#   'M',
#   'julio1@hotmail.com',
#   '(62) 93391-5891',
#   70000,
#   0,
#   'Pós-graduado'),
#  (5,
#   'Janet',
#   'Alvarez',
#   '1985-12-01',
#   'S',
#   'F',
#   'janet9@gmail.com',
#   '(21) 93379-3743',
#   70000,
#   0,
#   'Pós-graduado')]

# %% [markdown]
# # Selecionar todas as linhas da tabela produtos, Mas, quero ordenar pela coluna Preco_unit, ou cliente pela renda_anual

# %%
#maior por menor
#menor para o maior
query = "SELECT * FROM clientes ORDER BY Renda_anual ASC;" # =>menor para o maior
cursor.execute(query)

crescente= cursor.fetchall()

display(crescente)
# Out:
# [(23,
#   'Alejandro',
#   'Beck',
#   '1965-12-18',
#   'C',
#   'M',
#   'alejandro45@gmail.com',
#   '(85) 94492-9582',
#   10000,
#   2,
#   'Parcial'),
#  (28,
#   'Bethany',
#   'Yuan',
#   '1967-02-17',
#   'C',
#   'F',
#   'bethany10@hotmail.com',
#   '(62) 92998-6359',
#   10000,
#   2,
#   'Parcial'),
#  (33,
#   'Wendy',
#   'Dominguez',
#   '1968-02-19',
#   'C',
#   'F',
#   'wendy12@gmail.com',
#   '(31) 97278-7135',
#   10000,
#   2,
#   'Parcial'),
#  (36,
#   'Diana',
#   'Hernandez',
#   '1968-03-18',
#   'C',
#   'F',
#   'diana2@gmail.com',
#   '(85) 93094-3166',
#   10000,
#   2,
#   'Parcial'),
#  (32,
#   'Ebony',
#   'Gonzalez',
#   '1967-06-14',
#   'C',
#   'F',
#   'ebony19@gmail.com',
#   '(71) 99664-2156',
#   20000,
#   4,
#   'Ensino médio'),
#  (16,
#   'Shannon',
#   'Wang',
#   '1964-06-21',
#   'S',
#   'F',
#   'shannon1@hotmail.com',
#   '(71) 94496-1712',
#   20000,
#   4,
#   'Ensino médio'),
#  (29,
#   'Theresa',
#   'Ramos',
# ...

# %%
dfcre = pd.read_sql(query, conexao)

# Exiba o DataFrame
display(dfcre)
# Out:
# /tmp/ipykernel_8614/2226919468.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dfcre = pd.read_sql(query, conexao)
#     ID_Cliente       Nome  Sobrenome Data_Nascimento Estado_Civil Sexo  \
# 0           23  Alejandro       Beck      1965-12-18            C    M
# 1           28    Bethany       Yuan      1967-02-17            C    F
# 2           33      Wendy  Dominguez      1968-02-19            C    F
# 3           36      Diana  Hernandez      1968-03-18            C    F
# 4           32      Ebony   Gonzalez      1967-06-14            C    F
# ..         ...        ...        ...             ...          ...  ...
# 95          79   Savannah      Baker      1986-07-19            C    F
# 96          81     Alyssa        Cox      1986-03-10            C    F
# ...

# %% [markdown]
# # agora maior para o menor DECRESCENTE

# %%
#Selecionar todas as linhas da tabela produtos, Mas, quero ordenar pela coluna Preco_unit, ou cliente pela renda_anual
#maior por menor
#menor para o maior
query = "SELECT * FROM clientes ORDER BY Renda_anual DESC;"
#cursor.execute(query)

cursor.execute(query)

des= cursor.fetchall()

display(des)
# Out:
# [(78,
#   'Damien',
#   'Chander',
#   '1979-07-12',
#   'C',
#   'M',
#   'damien32@gmail.com',
#   '(11) 97494-2293',
#   170000,
#   0,
#   'Graduação'),
#  (77,
#   'Donald',
#   'Gonzalez',
#   '1979-03-06',
#   'S',
#   'M',
#   'donald20@gmail.com',
#   '(31) 96897-9735',
#   160000,
#   0,
#   'Graduação'),
#  (80,
#   'Angela',
#   'Butler',
#   '1986-07-30',
#   'S',
#   'F',
#   'angela17@gmail.com',
#   '(31) 99100-6309',
#   130000,
#   0,
#   'Graduação'),
#  (81,
#   'Alyssa',
#   'Cox',
#   '1986-03-10',
#   'C',
#   'F',
#   'alyssa37@gmail.com',
#   '(11) 94546-6962',
#   130000,
#   0,
#   'Graduação'),
#  (79,
#   'Savannah',
#   'Baker',
#   '1986-07-19',
#   'C',
#   'F',
#   'savannah39@gmail.com',
#   '(11) 98574-8482',
#   120000,
#   2,
#   'Pós-graduado'),
#  (91,
#   'Aimee',
#   'He',
#   '1987-09-05',
#   'C',
#   'F',
#   'aimee13@gmail.com',
#   '(71) 94329-9879',
#   100000,
#   0,
#   'Graduação'),
#  (11,
#   'Lauren',
#   'Walker',
# ...

# %%
dfdes = pd.read_sql(query, conexao)
print('Decrescente dados  da renda anual dos bancos de dados de clientes')
# Exiba o DataFrame
display(dfdes)
# Out:
# Decrescente dados  da renda anual dos bancos de dados de clientes
# /tmp/ipykernel_8614/1865137445.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dfdes = pd.read_sql(query, conexao)
#     ID_Cliente       Nome  Sobrenome Data_Nascimento Estado_Civil Sexo  \
# 0           78     Damien    Chander      1979-07-12            C    M
# 1           77     Donald   Gonzalez      1979-03-06            S    M
# 2           80     Angela     Butler      1986-07-30            S    F
# 3           81     Alyssa        Cox      1986-03-10            C    F
# 4           79   Savannah      Baker      1986-07-19            C    F
# ..         ...        ...        ...             ...          ...  ...
# 95          42       Adam     Flores      1969-05-19            C    M
# ...

# %%
query = "SELECT * FROM clientes ORDER BY Qtd_Filhos DESC;"
#cursor.execute(query)

cursor.execute(query)

des= cursor.fetchall()

display(des)
# Out:
# [(100,
#   'Julia',
#   'Nelson',
#   '1985-04-16',
#   'S',
#   'F',
#   'julia7@outlook.com',
#   '(41) 96066-9929',
#   80000,
#   5,
#   'Pós-graduado'),
#  (3,
#   'Elizabeth',
#   'Johnson',
#   '1988-08-03',
#   'S',
#   'F',
#   'elizabeth5@gmail.com',
#   '(31) 92039-5832',
#   80000,
#   5,
#   'Pós-graduado'),
#  (10,
#   'Curtis',
#   'Lu',
#   '1983-10-30',
#   'C',
#   'M',
#   'curtis9@outlook.com',
#   '(71) 94509-1440',
#   60000,
#   4,
#   'Pós-graduado'),
#  (29,
#   'Theresa',
#   'Ramos',
#   '1967-08-17',
#   'C',
#   'F',
#   'theresa13@hotmail.com',
#   '(71) 92187-3667',
#   20000,
#   4,
#   'Ensino médio'),
#  (16,
#   'Shannon',
#   'Wang',
#   '1964-06-21',
#   'S',
#   'F',
#   'shannon1@hotmail.com',
#   '(71) 94496-1712',
#   20000,
#   4,
#   'Ensino médio'),
#  (30,
#   'Denise',
#   'Stone',
#   '1967-06-06',
#   'C',
#   'F',
#   'denise10@hotmail.com',
#   '(62) 94170-5754',
#   20000,
#   4,
#   'Ensino médio'),
#  (31,
#   'Jaime',
#   'Nath',
# ...

# %%
dfdes = pd.read_sql(query, conexao)
print('Decrescente dados de quantidades de filhos dos bancos de dados de clientes')
# Exiba o DataFrame
display(dfdes)
# Out:
# Decrescente dados de quantidades de filhos dos bancos de dados de clientes
# /tmp/ipykernel_8614/3983087713.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dfdes = pd.read_sql(query, conexao)
#     ID_Cliente       Nome  Sobrenome Data_Nascimento Estado_Civil Sexo  \
# 0          100      Julia     Nelson      1985-04-16            S    F
# 1            3  Elizabeth    Johnson      1988-08-03            S    F
# 2           10     Curtis         Lu      1983-10-30            C    M
# 3           29    Theresa      Ramos      1967-08-17            C    F
# 4           16    Shannon       Wang      1964-06-21            S    F
# ..         ...        ...        ...             ...          ...  ...
# 95          60       Noah     Powell      1995-08-28            C    M
# ...

# %%
# dados pelo SQL com renda acima dos 20000

# %%
query = "SELECT * FROM clientes WHERE Renda_Anual >= 20000;"

dfpreco = pd.read_sql(query, conexao)

# Exiba o DataFrame
print('Renda acima de 20000 reis')

display(dfpreco)
# Out:
# Renda acima de 20000 reis
# /tmp/ipykernel_8614/71271482.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dfpreco = pd.read_sql(query, conexao)
#     ID_Cliente       Nome Sobrenome Data_Nascimento Estado_Civil Sexo  \
# 0            1      Ruben    Torres      1985-08-07            C    M
# 1            2    Christy       Zhu      1988-02-10            S    F
# 2            3  Elizabeth   Johnson      1988-08-03            S    F
# 3            4      Julio      Ruiz      1985-07-31            S    M
# 4            5      Janet   Alvarez      1985-12-01            S    F
# ..         ...        ...       ...             ...          ...  ...
# 91          96    Mallory     Rubio      1981-04-26            S    F
# 92          97       Adam      Ross      1981-03-03            C    M
# ...

# %%
#  Criando Filtros no SQL com o Comando WHERE - Curso de SQL - Aula 3 
print('renda igual aos R$70000')
query = "SELECT * FROM clientes WHERE Renda_Anual = 70000;"
dfpreco2 = pd.read_sql(query, conexao)

# Exiba o DataFrame
display(dfpreco2)
# Out:
# renda igual aos R$70000
# /tmp/ipykernel_8614/3214286703.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dfpreco2 = pd.read_sql(query, conexao)
#     ID_Cliente       Nome Sobrenome Data_Nascimento Estado_Civil Sexo  \
# 0            2    Christy       Zhu      1988-02-10            S    F
# 1            4      Julio      Ruiz      1985-07-31            S    M
# 2            5      Janet   Alvarez      1985-12-01            S    F
# 3            8    Shannon   Carlson      1984-03-27            S    M
# 4            9  Jacquelyn    Suarez      1984-02-01            S    F
# 5           40      Megan   Sanchez      1997-06-08            C    F
# 6           55       Carl  Andersen      1973-10-07            C    M
# 7           64      Grace    Butler      1993-11-22            C    F
# ...

# %%
print('cliente em texto ou nome , da Janet')


query = "SELECT * FROM clientes WHERE Nome = 'Janet';"
dfpreco3 = pd.read_sql(query, conexao)

# Exiba o DataFrame
display(dfpreco3)
# Out:
# cliente em texto ou nome , da Janet
# /tmp/ipykernel_8614/76032101.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dfpreco3 = pd.read_sql(query, conexao)
#    ID_Cliente   Nome Sobrenome Data_Nascimento Estado_Civil Sexo  \
# 0           5  Janet   Alvarez      1985-12-01            S    F
#
#               Email         Telefone  Renda_Anual  Qtd_Filhos  Escolaridade
# 0  janet9@gmail.com  (21) 93379-3743        70000           0  Pós-graduado

# %%
query = "SELECT * FROM clientes WHERE Sobrenome = 'Alvarez' OR Sobrenome = 'Brown';"
dfname3 = pd.read_sql(query, conexao)
print('sobrenomes Alvares ou Brown')
# Exiba o DataFrame
display(dfname3)
# Out:
# sobrenomes Alvares ou Brown
# /tmp/ipykernel_8614/4092345128.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dfname3 = pd.read_sql(query, conexao)
#    ID_Cliente   Nome Sobrenome Data_Nascimento Estado_Civil Sexo  \
# 0           5  Janet   Alvarez      1985-12-01            S    F
# 1          84   Ryan     Brown      1977-12-18            C    M
#
#               Email         Telefone  Renda_Anual  Qtd_Filhos  Escolaridade
# 0  janet9@gmail.com  (21) 93379-3743        70000           0  Pós-graduado
# 1  ryan43@gmail.com  (85) 92637-3025        70000           2       Parcial

# %%
print('filtrando no mysql')
query = "SELECT ID_Cliente, Sobrenome, Email, Renda_Anual, Telefone FROM clientes;"
dfprod = pd.read_sql(query, conexao)

# Exiba o DataFrame
display(dfprod)
# Out:
# filtrando no mysql
# /tmp/ipykernel_8614/2840187453.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dfprod = pd.read_sql(query, conexao)
#     ID_Cliente Sobrenome                  Email  Renda_Anual         Telefone
# 0            1    Torres    ruben35@hotmail.com        60000  (85) 94132-1176
# 1            2       Zhu  christy12@hotmail.com        70000  (41) 96270-6086
# 2            3   Johnson   elizabeth5@gmail.com        80000  (31) 92039-5832
# 3            4      Ruiz     julio1@hotmail.com        70000  (62) 93391-5891
# 4            5   Alvarez       janet9@gmail.com        70000  (21) 93379-3743
# ..         ...       ...                    ...          ...              ...
# 95          96     Rubio   mallory7@hotmail.com        60000  (62) 93152-6617
# ...

# %%
# Fechar o cursor e a conexão
#cursor.close()
#conexao.close()

# %% [markdown]
# # data específica

# %%
query = "SELECT * FROM clientes WHERE Data_Nascimento = '1984-02-01';"
dfdata = pd.read_sql(query, conexao)

# Exiba o DataFrame
display(dfdata)
# Out:
# /tmp/ipykernel_8614/274271265.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dfdata = pd.read_sql(query, conexao)
#    ID_Cliente       Nome Sobrenome Data_Nascimento Estado_Civil Sexo  \
# 0           9  Jacquelyn    Suarez      1984-02-01            S    F
#
#                      Email         Telefone  Renda_Anual  Qtd_Filhos  \
# 0  jacquelyn20@hotmail.com  (31) 98159-7254        70000           0
#
#    Escolaridade
# 0  Pós-graduado

# %%
query = "SELECT * FROM clientes WHERE Data_Nascimento = '1984-02-01' AND Renda_Anual > 5000;"
dfdata2 = pd.read_sql(query, conexao)

# Exiba o DataFrame
display(dfdata2)
# Out:
# /tmp/ipykernel_8614/1657006879.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dfdata2 = pd.read_sql(query, conexao)
#    ID_Cliente       Nome Sobrenome Data_Nascimento Estado_Civil Sexo  \
# 0           9  Jacquelyn    Suarez      1984-02-01            S    F
#
#                      Email         Telefone  Renda_Anual  Qtd_Filhos  \
# 0  jacquelyn20@hotmail.com  (31) 98159-7254        70000           0
#
#    Escolaridade
# 0  Pós-graduado

# %%
#query = "SELECT * FROM pedidos WHERE Data_Venda >= '2019-01-03';"
print('nasceu depois de 1979 e com renda abaixo dos 50000')
query = "SELECT * FROM clientes WHERE Data_Nascimento >= '1980-01-01' AND Renda_Anual < 50000;"

dfdata3 = pd.read_sql(query, conexao)

# Exiba o DataFrame
display(dfdata3)
# Out:
# nasceu depois de 1979 e com renda abaixo dos 50000
# /tmp/ipykernel_8614/484289044.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dfdata3 = pd.read_sql(query, conexao)
#     ID_Cliente     Nome Sobrenome Data_Nascimento Estado_Civil Sexo  \
# 0           14    Chloe     Young      1999-02-22            S    F
# 1           15    Wyatt      Hill      1999-04-23            C    M
# 2           18   Jordan      King      1998-09-15            S    M
# 3           19  Destiny    Wilson      1998-08-29            S    F
# 4           20    Ethan     Zhang      1998-10-07            C    M
# 5           21     Seth   Edwards      1998-10-06            C    M
# 6           35    Chloe    Garcia      1997-11-22            S    F
# 7           38    Jesse    Murphy      1997-07-27            C    M
# ...

# %%
# Fechar o cursor e a conexão
cursor.close()
conexao.close()

# %%
import mysql.connector

# Configurar a conexão com o banco de dados
conexao = mysql.connector.connect(
    host='localhost',
    user='root',
    password='admin',
    database='clientes_banco_backup',
)

# Criar um cursor
cursor = conexao.cursor()

# %%
#query = "SELECT * FROM pedidos"

#cursor.execute(query)

cursor.execute("SHOW TABLES")

# Obter todos os resultados da consulta
resultados = cursor.fetchall()

# Exibir os resultados
for linha in resultados:
    print(linha)
# Out:
# ('clientes',)

# %%
# Executar a consulta SQL para selecionar todos os dados da tabela
query = "SELECT * FROM clientes"
dfcli = pd.read_sql(query, conexao)

# Exiba o DataFrame
display(dfcli)
# Out:
# /tmp/ipykernel_8614/565086174.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dfcli = pd.read_sql(query, conexao)
#     ID_Cliente       Nome Sobrenome Data_Nascimento Estado_Civil Sexo  \
# 0            1      Ruben    Torres      1985-08-07            C    M
# 1            2    Christy       Zhu      1988-02-10            S    F
# 2            3  Elizabeth   Johnson      1988-08-03            S    F
# 3            4      Julio      Ruiz      1985-07-31            S    M
# 4            5      Janet   Alvarez      1985-12-01            S    F
# ..         ...        ...       ...             ...          ...  ...
# 95          96    Mallory     Rubio      1981-04-26            S    F
# 96          97       Adam      Ross      1981-03-03            C    M
# ...

# %%
print('Clientes solteiros')
query = "SELECT * FROM clientes WHERE Estado_Civil = 'S';"
dfc1 = pd.read_sql(query, conexao)

# Exiba o DataFrame
display(dfc1)
# Out:
# Clientes solteiros
# /tmp/ipykernel_8614/4029083662.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dfc1 = pd.read_sql(query, conexao)
#     ID_Cliente       Nome Sobrenome Data_Nascimento Estado_Civil Sexo  \
# 0            2    Christy       Zhu      1988-02-10            S    F
# 1            3  Elizabeth   Johnson      1988-08-03            S    F
# 2            4      Julio      Ruiz      1985-07-31            S    M
# 3            5      Janet   Alvarez      1985-12-01            S    F
# 4            7        Rob   Verhoff      1984-07-02            S    F
# 5            8    Shannon   Carlson      1984-03-27            S    M
# 6            9  Jacquelyn    Suarez      1984-02-01            S    F
# 7           13     Sydney   Bennett      1988-05-04            S    F
# ...

# %%
print('Clientes solteiros e do sexo masculino')
query = "SELECT * FROM clientes WHERE Estado_Civil = 'S' AND Sexo ='M';"
dfc2 = pd.read_sql(query, conexao)

# Exiba o DataFrame
display(dfc2)
# Out:
# Clientes solteiros e do sexo masculino
# /tmp/ipykernel_8614/2052000984.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dfc2 = pd.read_sql(query, conexao)
#     ID_Cliente      Nome Sobrenome Data_Nascimento Estado_Civil Sexo  \
# 0            4     Julio      Ruiz      1985-07-31            S    M
# 1            8   Shannon   Carlson      1984-03-27            S    M
# 2           17  Clarence       Rai      1964-10-04            S    M
# 3           18    Jordan      King      1998-09-15            S    M
# 4           24    Harold       Sai      1966-03-29            S    M
# 5           43   Leonard      Nara      1970-05-14            S    M
# 6           49    Daniel   Johnson      1971-07-30            S    M
# 7           65     Caleb    Carter      1996-09-20            S    M
# ...

# %%
# Fechar o cursor e a conexão
cursor.close()
conexao.close()
